# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# Get data stock data
aapl = yf.download("AAPL", start="2023-1-1", end="2024-1-1", interval="1d")

# Add average candle price
aapl['avg'] = np.min(aapl['Open']) + np.abs(aapl['Open'] - aapl['Close'])/2

# Store average candle prices
avg_prices = np.round(list(aapl['avg']), 2)

aapl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  130.279999  130.899994  124.169998  125.070000  124.048042
# 2023-01-04  126.889999  128.660004  125.080002  126.360001  125.327507
# 2023-01-05  127.129997  127.769997  124.760002  125.019997  123.998451
# 2023-01-06  126.010002  130.289993  124.889999  129.619995  128.560867
# 2023-01-09  130.470001  133.410004  129.889999  130.149994  129.086533
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.091385
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.542816
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.642548
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.071426
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.024185
#
#                Volume         avg
# ...

# %%
avg_prices
# Out:
# array([128.62, 126.28, 127.07, 127.81, 126.17, 126.25, 127.13, 126.25,
#        127.38, 126.57, 126.82, 126.61, 127.31, 127.51, 127.12, 126.5 ,
#        126.41, 127.39, 126.99, 126.81, 126.74, 126.97, 129.25, 126.43,
#        128.01, 126.99, 127.47, 126.78, 127.46, 126.55, 127.12, 126.11,
#        126.11, 126.87, 126.03, 126.36, 126.21, 126.11, 126.19, 126.77,
#        126.78, 127.51, 126.03, 127.06, 126.04, 127.5 , 126.87, 127.34,
#        126.67, 126.91, 127.86, 126.55, 127.17, 126.99, 126.75, 126.06,
#        126.71, 126.84, 126.17, 126.71, 126.43, 127.24, 126.96, 126.5 ,
#        126.5 , 127.13, 126.32, 126.79, 126.57, 127.97, 126.32, 126.08,
#        126.19, 126.93, 126.29, 126.03, 126.18, 126.72, 126.36, 127.62,
#        126.6 , 126.17, 126.79, 127.04, 126.46, 127.31, 126.52, 126.65,
#        126.28, 126.06, 126.53, 126.56, 126.05, 126.5 , 127.04, 126.62,
#        126.12, 126.8 , 126.39, 126.3 , 127.06, 126.18, 126.05, 127.21,
# ...
